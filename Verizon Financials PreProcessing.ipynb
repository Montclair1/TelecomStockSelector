# %%
import time
start_time = time.time()

# %%
import pandas as pd
data1 = pd.read_csv("VerizonFinancialsCleaned.csv")
data1.head()
# Out:
#          Date  StockPrice  TTMNetEPS  TTMSalesperShare  PricetoSalesRatio  \
# 0  12/31/2006       19.46       2.12             29.96               0.65
# 1   3/31/2007       20.04       2.07             30.56               0.66
# 2   6/30/2007       21.98       2.10             31.14               0.71
# 3   9/30/2007       23.88       1.88             31.66               0.75
# 4  12/31/2007       23.78       1.90             32.18               0.74
#
#    BookValueperShare  TTMFCFperShare  QuarterlyRevenue  GrossProfit  \
# 0              16.67            6.23             22606        13454
# 1              16.80            5.66             22584        13672
# 2              17.17            5.41             23273        14042
# 3              17.19            4.96             23772        14164
# 4              17.58            5.78             23840        14044
#
#    OperatingIncome        ...         CurrentLiabilities  \
# 0             3444        ...                      32.28
# 1             3796        ...                      27.91
# 2             4149        ...                      24.45
# 3             4210        ...                      24.16
# 4             3423        ...                      24.74
#
#    CurrentAssetsInventory  QuickRatio  DebtToEquity Ratio  TTMNetIncome  \
# 0                   21.02        0.65                0.59         13.37
# 1                   16.11        0.58                0.58         13.99
# 2                   15.24        0.62                0.59         14.93
# 3                   15.25        0.63                0.59         15.60
# 4                   16.97        0.69                0.56         15.58
#
#    LTInvestmentsDebt  TotalAssets  CashOnHand  LongTermDebt  TotalLiabilities
# 0              77.18       188804        5653         28646            140269
# 1              76.86       184284        3450         28073            135502
# 2              79.21       184760        2356         29374            134929
# 3              79.07       185619        1909         29383            135930
# 4              78.78       186959        3397         28203            136378
#
# [5 rows x 24 columns]

# %%
import numpy as np
# normalize data with natural log of difference between each day, add as extra row
# lognormal = percentage change per day, but can add or subtract cumulatively, unlike percentage
data1['ln StockPrice']=np.log(data1.StockPrice/data1.StockPrice.shift(1))
data1.head()
# Out:
#          Date  StockPrice  TTMNetEPS  TTMSalesperShare  PricetoSalesRatio  \
# 0  12/31/2006       19.46       2.12             29.96               0.65
# 1   3/31/2007       20.04       2.07             30.56               0.66
# 2   6/30/2007       21.98       2.10             31.14               0.71
# 3   9/30/2007       23.88       1.88             31.66               0.75
# 4  12/31/2007       23.78       1.90             32.18               0.74
#
#    BookValueperShare  TTMFCFperShare  QuarterlyRevenue  GrossProfit  \
# 0              16.67            6.23             22606        13454
# 1              16.80            5.66             22584        13672
# 2              17.17            5.41             23273        14042
# 3              17.19            4.96             23772        14164
# 4              17.58            5.78             23840        14044
#
#    OperatingIncome      ...        CurrentAssetsInventory  QuickRatio  \
# 0             3444      ...                         21.02        0.65
# 1             3796      ...                         16.11        0.58
# 2             4149      ...                         15.24        0.62
# 3             4210      ...                         15.25        0.63
# 4             3423      ...                         16.97        0.69
#
#    DebtToEquity Ratio  TTMNetIncome  LTInvestmentsDebt  TotalAssets  \
# 0                0.59         13.37              77.18       188804
# 1                0.58         13.99              76.86       184284
# 2                0.59         14.93              79.21       184760
# 3                0.59         15.60              79.07       185619
# 4                0.56         15.58              78.78       186959
#
#    CashOnHand  LongTermDebt  TotalLiabilities  ln StockPrice
# 0        5653         28646            140269            NaN
# 1        3450         28073            135502       0.029369
# 2        2356         29374            134929       0.092403
# 3        1909         29383            135930       0.082908
# 4        3397         28203            136378      -0.004196
#
# [5 rows x 25 columns]

# %%
#create new dataframe copy the columns and normalize the StockPrice column
#lognormal = percentage change per day, but can add or subtract cumulatively, unlike percentage
data1norm = data1.filter(['Date'], axis=1)
data1norm['StockPrice'] = data1['StockPrice']
data1norm['Log Normal StockPrice']=np.log(data1.StockPrice/data1.StockPrice.shift(1))

# %%
data1norm.head()
# Out:
#          Date  StockPrice  Log Normal StockPrice
# 0  12/31/2006       19.46                    NaN
# 1   3/31/2007       20.04               0.029369
# 2   6/30/2007       21.98               0.092403
# 3   9/30/2007       23.88               0.082908
# 4  12/31/2007       23.78              -0.004196

# %%
# check for all rows with null values eliminate at the end
nan = data1norm[data1norm.isnull().any(axis=1)]
nan
# Out:
#          Date  StockPrice  Log Normal StockPrice
# 0  12/31/2006       19.46                    NaN

# %%
#create new dataframe for ratios
data1ratios = data1norm.filter(['Date'], axis=1)
data1ratios['ln StockPrice']=data1['ln StockPrice']

#calculate the ratios

#PE Ratio = StockPrice/TTMNetEPS
#Description: 
data1ratios['PE Ratio'] = np.around((data1['StockPrice']/data1['TTMNetEPS']), decimals=2)

#PricetoBook Ratio = StockPrice/BookValueperShare
#Description: 
data1ratios['PricetoBook Ratio'] = np.around((data1['StockPrice'])/data1['BookValueperShare'], decimals=2)

#Current Ratio = TotalAssets/TotalLiabilities
#Description: 
data1ratios['Current Ratio'] = np.around((data1['CurrentAssets']/data1['CurrentLiabilities']), decimals=2)

#Shareholder Equity = TotalAssets - TotalLiabilities
#Description: 
data1ratios['Shareholder Equity'] = (data1['TotalAssets'] - data1['TotalLiabilities'])

#DebtToEquity Ratio = LongTermDebt / Shareholder Equity
#Description: 
data1ratios['DebtToEquity Ratio'] = np.around((data1['LongTermDebt'] / data1ratios['Shareholder Equity']), decimals=2)

#ROI = TTMNetIncome/LTInvestmentsDebt
#Description: 
data1ratios['ROI'] = (data1['TTMNetIncome']/data1['LTInvestmentsDebt'])

data1ratios.head()
# Out:
#          Date  ln StockPrice  PE Ratio  PricetoBook Ratio  Current Ratio  \
# 0  12/31/2006            NaN      9.18               1.17           0.70
# 1   3/31/2007       0.029369      9.68               1.19           0.64
# 2   6/30/2007       0.092403     10.47               1.28           0.70
# 3   9/30/2007       0.082908     12.70               1.39           0.71
# 4  12/31/2007      -0.004196     12.52               1.35           0.76
#
#    Shareholder Equity  DebtToEquity Ratio       ROI
# 0               48535                0.59  0.173231
# 1               48782                0.58  0.182019
# 2               49831                0.59  0.188486
# 3               49689                0.59  0.197294
# 4               50581                0.56  0.197766

# %%
#Make data frame for Net Income and Revenue as percentages here
data1percentages = data1.filter(['Date'], axis=1)
data1percentages['Net Income % Change'] = (((data1.NetIncome - data1.NetIncome.shift(1))/data1.NetIncome.shift(1))*100)
data1percentages['Revenue % Change'] = (((data1.QuarterlyRevenue - data1.QuarterlyRevenue.shift(1))/data1.QuarterlyRevenue.shift(1))*100)
data1percentages.head()
# Out:
#          Date  Net Income % Change  Revenue % Change
# 0  12/31/2006                  NaN               NaN
# 1   3/31/2007            44.864341         -0.097319
# 2   6/30/2007            12.575251          3.050832
# 3   9/30/2007           -24.480095          2.144115
# 4  12/31/2007           -15.656963          0.286051

# %%
#categorize current ratio numerical values
# Current Ratio
bins = [0, .5, 1.0, 1.5, 2.0, np.inf]
names = ['Very Low', 'Low', 'Acceptable', 'Good', 'Very Good']
data1ratios['Current Ratio Category'] = pd.cut(data1ratios['Current Ratio'], bins, labels=names)
# Price change categories
bins = [np.NINF,-.12, -.06, 0, .06, .12, np.inf]
names = [ 'Extremely Negative','Very Negative', 'Negative', 'Positive', 'Very Positive','Extremely Positive']
data1ratios['LN Price Change'] = pd.cut(data1ratios['ln StockPrice'], bins, labels=names)
data1ratios.head()
# Out:
#          Date  ln StockPrice  PE Ratio  PricetoBook Ratio  Current Ratio  \
# 0  12/31/2006            NaN      9.18               1.17           0.70
# 1   3/31/2007       0.029369      9.68               1.19           0.64
# 2   6/30/2007       0.092403     10.47               1.28           0.70
# 3   9/30/2007       0.082908     12.70               1.39           0.71
# 4  12/31/2007      -0.004196     12.52               1.35           0.76
#
#    Shareholder Equity  DebtToEquity Ratio       ROI Current Ratio Category  \
# 0               48535                0.59  0.173231                    Low
# 1               48782                0.58  0.182019                    Low
# 2               49831                0.59  0.188486                    Low
# 3               49689                0.59  0.197294                    Low
# 4               50581                0.56  0.197766                    Low
#
#   Lognorm Price Category LN Price Change
# 0                    NaN             NaN
# 1               Positive        Positive
# 2          Very Positive   Very Positive
# 3          Very Positive   Very Positive
# 4               Negative        Negative

# %%
# combine all preproccessed data to a final data frame
data1final = data1.filter(['Date'], axis=1)
data1final['StockPrice'] = data1['StockPrice']
data1final['Log Normal StockPrice'] = data1norm['Log Normal StockPrice']
data1final['LN Price Change'] = data1ratios['LN Price Change']
data1final['TTMNetEPS'] = data1['TTMNetEPS']
data1final['PE Ratio'] = data1ratios['PE Ratio']
data1final['TTMSalesperShare'] = data1['TTMSalesperShare']
data1final['PricetoSalesRatio'] = data1['PricetoSalesRatio']
data1final['BookValueperShare'] = data1['BookValueperShare']
data1final['PricetoBook Ratio'] = data1ratios['PricetoBook Ratio']
data1final['TTMFCFperShare'] = data1['TTMFCFperShare']
data1final['QuarterlyRevenue'] = data1['QuarterlyRevenue']
data1final['Quarterly Revenue % Change'] = np.around(data1percentages['Revenue % Change'], decimals=2)
data1final['GrossProfit'] = data1['GrossProfit']
data1final['OperatingIncome'] = data1['OperatingIncome']
data1final['EBITDA'] = data1['EBITDA']
data1final['NetIncome'] = data1['NetIncome']
data1final['Net Income % Change'] = np.around(data1percentages['Net Income % Change'], decimals=2)
data1final['EPS'] = data1['EPS']
data1final['CurrentAssets'] = data1['CurrentAssets']
data1final['CurrentLiabilities'] = data1['CurrentLiabilities']
data1final['CurrentAssetsInventory'] = data1['CurrentAssetsInventory']
data1final['OperatingIncome'] = data1['CurrentAssetsInventory']
data1final['QuickRatio'] = data1['QuickRatio']
data1final['DebtToEquity Ratio'] = data1['DebtToEquity Ratio']
data1final['TTMNetIncome'] = data1['TTMNetIncome']
data1final['LTInvestmentsDebt'] = data1['LTInvestmentsDebt']
data1final['ROI'] = data1ratios['ROI']
data1final['TotalAssets'] = data1['TotalAssets']
data1final['TotalLiabilities'] = data1['TotalLiabilities']
data1final['Current Ratio'] = data1ratios['Current Ratio']
data1final['Current Ratio Category'] = data1ratios['Current Ratio Category']
data1final['CashOnHand'] = data1['CashOnHand']
data1final['LongTermDebt'] = data1['LongTermDebt']
data1final['Shareholder Equity'] = data1ratios['Shareholder Equity']
data1final['DebtToEquity Ratio'] = data1ratios['DebtToEquity Ratio']

# %%
# check for all rows with null values
nan = data1final[data1final.isnull().any(axis=1)]
nan
# Out:
#          Date  StockPrice  Log Normal StockPrice LN Price Change  TTMNetEPS  \
# 0  12/31/2006       19.46                    NaN             NaN       2.12
#
#    PE Ratio  TTMSalesperShare  PricetoSalesRatio  BookValueperShare  \
# 0      9.18             29.96               0.65              16.67
#
#    PricetoBook Ratio         ...          TTMNetIncome  LTInvestmentsDebt  \
# 0               1.17         ...                 13.37              77.18
#
#         ROI  TotalAssets  TotalLiabilities  Current Ratio  \
# 0  0.173231       188804            140269            0.7
#
#    Current Ratio Category  CashOnHand  LongTermDebt  Shareholder Equity
# 0                     Low        5653         28646               48535
#
# [1 rows x 34 columns]

# %%
#drop the first row which contains null value
#To improve make this code work to drop any rows with null values instead of manually seeing its just the first row
data1final = data1final.drop(data1final.index[0])
data1final.head()
# Out:
#          Date  StockPrice  Log Normal StockPrice     LN Price Change  \
# 2   6/30/2007       21.98               0.092403       Very Positive
# 3   9/30/2007       23.88               0.082908       Very Positive
# 4  12/31/2007       23.78              -0.004196            Negative
# 5   3/31/2008       20.04              -0.171115  Extremely Negative
# 6   6/30/2008       19.78              -0.013059            Negative
#
#    TTMNetEPS  PE Ratio  TTMSalesperShare  PricetoSalesRatio  \
# 2       2.10     10.47             31.14               0.71
# 3       1.88     12.70             31.66               0.75
# 4       1.90     12.52             32.18               0.74
# 5       1.96     10.22             32.74               0.61
# 6       2.04      9.70             33.19               0.60
#
#    BookValueperShare  PricetoBook Ratio         ...          TTMNetIncome  \
# 2              17.17               1.28         ...                 14.93
# 3              17.19               1.39         ...                 15.60
# 4              17.58               1.35         ...                 15.58
# 5              17.64               1.14         ...                 16.12
# 6              17.87               1.11         ...                 16.51
#
#    LTInvestmentsDebt       ROI  TotalAssets  TotalLiabilities  Current Ratio  \
# 2              79.21  0.188486       184760            134929           0.70
# 3              79.07  0.197294       185619            135930           0.71
# 4              78.78  0.197766       186959            136378           0.76
# 5              82.41  0.195607       191293            141013           0.91
# 6              84.67  0.194992       200646            149759           0.60
#
#    Current Ratio Category  CashOnHand  LongTermDebt  Shareholder Equity
# 2                     Low        2356         29374               49831
# 3                     Low        1909         29383               49689
# 4                     Low        3397         28203               50581
# 5                     Low        7442         32134               50280
# 6                     Low        2074         33778               50887
#
# [5 rows x 34 columns]

# %%
#highlight new columns
def highlight_cols(s):
    color = 'yellow'
    return 'background-color: %s' % color

data1final.style.applymap(highlight_cols, subset=pd.IndexSlice[:, ['Log Normal StockPrice', 'PE Ratio', 'PricetoBook Ratio',
                        'Quarterly Revenue % Change','Net Income % Change','Current Ratio', 'Shareholder Equity', 'ROI', 'Current Ratio Category']])
# Out:
# <style  type="text/css" >
#     #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row0_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row1_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row2_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row3_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row4_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row5_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row6_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col17 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col26 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col29 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col30 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row7_col33 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row8_col2 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row8_col5 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row8_col9 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row8_col12 {
#             background-color:  yellow;
#         }    #T_c0339254_db2a_11e8_8026_a81e842825b7row8_col17 {
#             background-color:  yellow;

# %%
#export to csv
data1final.to_csv('VerizonPreProcessed.csv')
print("Preprocessing Completed In: %s seconds" % (time.time() - start_time))
# Out:
# Preprocessing Completed In: 4918.390425205231 seconds
