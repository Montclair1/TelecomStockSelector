# %%
import time
start_time = time.time()

# %%
import pandas as pd
data1 = pd.read_csv("VerizonFinancialsCleaned.csv")
data1.head()
# Out:
#          Date  StockPrice  TTMNetEPS  TTMSalesperShare  PricetoSalesRatio  \
# 0  12/31/2006       19.46       2.12             29.96               0.65
# 1   3/31/2007       20.04       2.07             30.56               0.66
# 2   6/30/2007       21.98       2.10             31.14               0.71
# 3   9/30/2007       23.88       1.88             31.66               0.75
# 4  12/31/2007       23.78       1.90             32.18               0.74
#
#    BookValueperShare  TTMFCFperShare  QuarterlyRevenue  GrossProfit  \
# 0              16.67            6.23             22606        13454
# 1              16.80            5.66             22584        13672
# 2              17.17            5.41             23273        14042
# 3              17.19            4.96             23772        14164
# 4              17.58            5.78             23840        14044
#
#    OperatingIncome        ...         CurrentLiabilities  \
# 0             3444        ...                      32.28
# 1             3796        ...                      27.91
# 2             4149        ...                      24.45
# 3             4210        ...                      24.16
# 4             3423        ...                      24.74
#
#    CurrentAssetsInventory  QuickRatio  DebtToEquity Ratio  TTMNetIncome  \
# 0                   21.02        0.65                0.59         13.37
# 1                   16.11        0.58                0.58         13.99
# 2                   15.24        0.62                0.59         14.93
# 3                   15.25        0.63                0.59         15.60
# 4                   16.97        0.69                0.56         15.58
#
#    LTInvestmentsDebt  TotalAssets  CashOnHand  LongTermDebt  TotalLiabilities
# 0              77.18       188804        5653         28646            140269
# 1              76.86       184284        3450         28073            135502
# 2              79.21       184760        2356         29374            134929
# 3              79.07       185619        1909         29383            135930
# 4              78.78       186959        3397         28203            136378
#
# [5 rows x 24 columns]

# %%
import numpy as np
# normalize data with natural log of difference between each day, add as extra row
# lognormal = percentage change per day, but can add or subtract cumulatively, unlike percentage
data1['ln StockPrice']=np.log(data1.StockPrice/data1.StockPrice.shift(1))
data1.head()
# Out:
#          Date  StockPrice  TTMNetEPS  TTMSalesperShare  PricetoSalesRatio  \
# 0  12/31/2006       19.46       2.12             29.96               0.65
# 1   3/31/2007       20.04       2.07             30.56               0.66
# 2   6/30/2007       21.98       2.10             31.14               0.71
# 3   9/30/2007       23.88       1.88             31.66               0.75
# 4  12/31/2007       23.78       1.90             32.18               0.74
#
#    BookValueperShare  TTMFCFperShare  QuarterlyRevenue  GrossProfit  \
# 0              16.67            6.23             22606        13454
# 1              16.80            5.66             22584        13672
# 2              17.17            5.41             23273        14042
# 3              17.19            4.96             23772        14164
# 4              17.58            5.78             23840        14044
#
#    OperatingIncome      ...        CurrentAssetsInventory  QuickRatio  \
# 0             3444      ...                         21.02        0.65
# 1             3796      ...                         16.11        0.58
# 2             4149      ...                         15.24        0.62
# 3             4210      ...                         15.25        0.63
# 4             3423      ...                         16.97        0.69
#
#    DebtToEquity Ratio  TTMNetIncome  LTInvestmentsDebt  TotalAssets  \
# 0                0.59         13.37              77.18       188804
# 1                0.58         13.99              76.86       184284
# 2                0.59         14.93              79.21       184760
# 3                0.59         15.60              79.07       185619
# 4                0.56         15.58              78.78       186959
#
#    CashOnHand  LongTermDebt  TotalLiabilities  ln StockPrice
# 0        5653         28646            140269            NaN
# 1        3450         28073            135502       0.029369
# 2        2356         29374            134929       0.092403
# 3        1909         29383            135930       0.082908
# 4        3397         28203            136378      -0.004196
#
# [5 rows x 25 columns]

# %%
#create new dataframe copy the columns and normalize the StockPrice column
#lognormal = percentage change per day, but can add or subtract cumulatively, unlike percentage
data1norm = data1.filter(['Date'], axis=1)
data1norm['StockPrice'] = data1['StockPrice']
data1norm['Log Normal StockPrice']=np.log(data1.StockPrice/data1.StockPrice.shift(1))

# %%
data1norm.head()
# Out:
#          Date  StockPrice  Log Normal StockPrice
# 0  12/31/2006       19.46                    NaN
# 1   3/31/2007       20.04               0.029369
# 2   6/30/2007       21.98               0.092403
# 3   9/30/2007       23.88               0.082908
# 4  12/31/2007       23.78              -0.004196

# %%
# check for all rows with null values eliminate at the end
#nan = data1norm[data1norm.isnull().any(axis=1)]
#nan

# %%
#drop the first row
#data1norm.drop(data1norm.index[0])

# %%
#create new dataframe for ratios
data1ratios = data1norm.filter(['Date'], axis=1)

#caclulate the ratios

#PE Ratio = StockPrice/TTMNetEPS
#Description: 
data1ratios['PE Ratio'] = np.around((data1['StockPrice']/data1['TTMNetEPS']), decimals=2) #should we trim these?

#PricetoBook Ratio = StockPrice/BookValueperShare
#Description: 
data1ratios['PricetoBook Ratio'] = np.around((data1['StockPrice'])/data1['BookValueperShare'], decimals=2)

#Current Ratio = TotalAssets/TotalLiabilities
#Description: 
data1ratios['Current Ratio'] = np.around((data1['CurrentAssets']/data1['CurrentLiabilities']), decimals=2)

#Shareholder Equity = TotalAssets - TotalLiabilities
#Description: 
data1ratios['Shareholder Equity'] = (data1['TotalAssets'] - data1['TotalLiabilities'])

#DebtToEquity Ratio = LongTermDebt - Shareholder Equity
#Description: 
data1ratios['DebtToEquity Ratio'] = np.around((data1['LongTermDebt'] / data1ratios['Shareholder Equity']), decimals=2)

#ROI = TTMNetIncome/LTInvestmentsDebt
#Description: 
data1ratios['ROI'] = (data1['TTMNetIncome']/data1['LTInvestmentsDebt'])

data1ratios.head()
# Out:
#          Date  PE Ratio  PricetoBook Ratio  Current Ratio  Shareholder Equity  \
# 0  12/31/2006      9.18               1.17           0.70               48535
# 1   3/31/2007      9.68               1.19           0.64               48782
# 2   6/30/2007     10.47               1.28           0.70               49831
# 3   9/30/2007     12.70               1.39           0.71               49689
# 4  12/31/2007     12.52               1.35           0.76               50581
#
#    DebtToEquity Ratio       ROI
# 0                0.59  0.173231
# 1                0.58  0.182019
# 2                0.59  0.188486
# 3                0.59  0.197294
# 4                0.56  0.197766

# %%
# Livio make data frame for Net Income and Revenue as percentages here
data1percentages = data1.filter(['Date'], axis=1)
data1percentages['Net Income % Change'] = (((data1.NetIncome - data1.NetIncome.shift(1))/data1.NetIncome.shift(1))*100)
data1percentages['Revenue % Change'] = (((data1.QuarterlyRevenue - data1.QuarterlyRevenue.shift(1))/data1.QuarterlyRevenue.shift(1))*100)
data1percentages.head()
# Out:
#          Date  Net Income % Change  Revenue % Change
# 0  12/31/2006                  NaN               NaN
# 1   3/31/2007            44.864341         -0.097319
# 2   6/30/2007            12.575251          3.050832
# 3   9/30/2007           -24.480095          2.144115
# 4  12/31/2007           -15.656963          0.286051

# %%
# combine all preproccessed data to a final data frame
data1final = data1.filter(['Date'], axis=1)
data1final['StockPrice'] = data1['StockPrice']
data1final['Log Normal StockPrice'] = data1norm['Log Normal StockPrice']
data1final['TTMNetEPS'] = data1['TTMNetEPS']
data1final['TTMSalesperShare'] = data1['TTMSalesperShare']
data1final['PricetoSalesRatio'] = data1['PricetoSalesRatio']
data1final['BookValueperShare'] = data1['BookValueperShare']
data1final['TTMFCFperShare'] = data1['TTMFCFperShare']
data1final['QuarterlyRevenue'] = data1['QuarterlyRevenue']
data1final['Quarterly Revenue % Change'] = np.around(data1percentages['Revenue % Change'], decimals=2)
data1final['GrossProfit'] = data1['GrossProfit']
data1final['OperatingIncome'] = data1['OperatingIncome']
data1final['EBITDA'] = data1['EBITDA']
data1final['NetIncome'] = data1['NetIncome']
data1final['Net Income % Change'] = np.around(data1percentages['Net Income % Change'], decimals=2)
data1final['EPS'] = data1['EPS']
data1final['CurrentAssets'] = data1['CurrentAssets']
data1final['CurrentLiabilities'] = data1['CurrentLiabilities']
data1final['CurrentAssetsInventory'] = data1['CurrentAssetsInventory']
data1final['OperatingIncome'] = data1['CurrentAssetsInventory']
data1final['QuickRatio'] = data1['QuickRatio']
data1final['DebtToEquity Ratio'] = data1['DebtToEquity Ratio']
data1final['TTMNetIncome'] = data1['TTMNetIncome']
data1final['LTInvestmentsDebt'] = data1['LTInvestmentsDebt']
data1final['TotalAssets'] = data1['TotalAssets']
data1final['CashOnHand'] = data1['CashOnHand']
data1final['LongTermDebt'] = data1['LongTermDebt']
data1final['TotalLiabilities'] = data1['TotalLiabilities']
data1final['PE Ratio'] = data1ratios['PE Ratio']
data1final['PricetoBook Ratio'] = data1ratios['PricetoBook Ratio']
data1final['Current Ratio'] = data1ratios['Current Ratio']
data1final['Shareholder Equity'] = data1ratios['Shareholder Equity']
data1final['DebtToEquity Ratio'] = data1ratios['DebtToEquity Ratio']
data1final['ROI'] = data1ratios['ROI']
data1final.head()
# Out:
#          Date  StockPrice  Log Normal StockPrice  TTMNetEPS  TTMSalesperShare  \
# 0  12/31/2006       19.46                    NaN       2.12             29.96
# 1   3/31/2007       20.04               0.029369       2.07             30.56
# 2   6/30/2007       21.98               0.092403       2.10             31.14
# 3   9/30/2007       23.88               0.082908       1.88             31.66
# 4  12/31/2007       23.78              -0.004196       1.90             32.18
#
#    PricetoSalesRatio  BookValueperShare  TTMFCFperShare  QuarterlyRevenue  \
# 0               0.65              16.67            6.23             22606
# 1               0.66              16.80            5.66             22584
# 2               0.71              17.17            5.41             23273
# 3               0.75              17.19            4.96             23772
# 4               0.74              17.58            5.78             23840
#
#    Quarterly Revenue % Change    ...     LTInvestmentsDebt  TotalAssets  \
# 0                         NaN    ...                 77.18       188804
# 1                       -0.10    ...                 76.86       184284
# 2                        3.05    ...                 79.21       184760
# 3                        2.14    ...                 79.07       185619
# 4                        0.29    ...                 78.78       186959
#
#    CashOnHand  LongTermDebt  TotalLiabilities  PE Ratio  PricetoBook Ratio  \
# 0        5653         28646            140269      9.18               1.17
# 1        3450         28073            135502      9.68               1.19
# 2        2356         29374            134929     10.47               1.28
# 3        1909         29383            135930     12.70               1.39
# 4        3397         28203            136378     12.52               1.35
#
#    Current Ratio  Shareholder Equity       ROI
# 0           0.70               48535  0.173231
# 1           0.64               48782  0.182019
# 2           0.70               49831  0.188486
# 3           0.71               49689  0.197294
# 4           0.76               50581  0.197766
#
# [5 rows x 32 columns]

# %%
# check for all rows with null values
nan = data1final[data1final.isnull().any(axis=1)]
nan
# Out:
#          Date  StockPrice  Log Normal StockPrice  TTMNetEPS  TTMSalesperShare  \
# 0  12/31/2006       19.46                    NaN       2.12             29.96
#
#    PricetoSalesRatio  BookValueperShare  TTMFCFperShare  QuarterlyRevenue  \
# 0               0.65              16.67            6.23             22606
#
#    Quarterly Revenue % Change    ...     LTInvestmentsDebt  TotalAssets  \
# 0                         NaN    ...                 77.18       188804
#
#    CashOnHand  LongTermDebt  TotalLiabilities  PE Ratio  PricetoBook Ratio  \
# 0        5653         28646            140269      9.18               1.17
#
#    Current Ratio  Shareholder Equity       ROI
# 0            0.7               48535  0.173231
#
# [1 rows x 32 columns]

# %%
#drop the first row which contains null value
#I want to somehow make this code work to drop any rows with null values instead of manually seeing its just the first row
data1final = data1final.drop(data1final.index[0])
data1final.head()
# Out:
#          Date  StockPrice  Log Normal StockPrice  TTMNetEPS  TTMSalesperShare  \
# 1   3/31/2007       20.04               0.029369       2.07             30.56
# 2   6/30/2007       21.98               0.092403       2.10             31.14
# 3   9/30/2007       23.88               0.082908       1.88             31.66
# 4  12/31/2007       23.78              -0.004196       1.90             32.18
# 5   3/31/2008       20.04              -0.171115       1.96             32.74
#
#    PricetoSalesRatio  BookValueperShare  TTMFCFperShare  QuarterlyRevenue  \
# 1               0.66              16.80            5.66             22584
# 2               0.71              17.17            5.41             23273
# 3               0.75              17.19            4.96             23772
# 4               0.74              17.58            5.78             23840
# 5               0.61              17.64            6.07             23833
#
#    Quarterly Revenue % Change    ...     LTInvestmentsDebt  TotalAssets  \
# 1                       -0.10    ...                 76.86       184284
# 2                        3.05    ...                 79.21       184760
# 3                        2.14    ...                 79.07       185619
# 4                        0.29    ...                 78.78       186959
# 5                       -0.03    ...                 82.41       191293
#
#    CashOnHand  LongTermDebt  TotalLiabilities  PE Ratio  PricetoBook Ratio  \
# 1        3450         28073            135502      9.68               1.19
# 2        2356         29374            134929     10.47               1.28
# 3        1909         29383            135930     12.70               1.39
# 4        3397         28203            136378     12.52               1.35
# 5        7442         32134            141013     10.22               1.14
#
#    Current Ratio  Shareholder Equity       ROI
# 1           0.64               48782  0.182019
# 2           0.70               49831  0.188486
# 3           0.71               49689  0.197294
# 4           0.76               50581  0.197766
# 5           0.91               50280  0.195607
#
# [5 rows x 32 columns]

# %%
#highlight new columns
def highlight_cols(s):
    color = 'yellow'
    return 'background-color: %s' % color

data1final.style.applymap(highlight_cols, subset=pd.IndexSlice[:, ['Log Normal StockPrice', 'PE Ratio', 'PricetoBook Ratio',
                        'Quarterly Revenue % Change','Net Income % Change','Current Ratio', 'Shareholder Equity', 'ROI']])
# Out:
# <style  type="text/css" >
#     #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow0_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow1_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow2_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow3_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow4_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow5_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow6_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow7_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col28 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col29 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col30 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow8_col31 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow9_col2 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow9_col9 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow9_col14 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow9_col27 {
#             background-color:  yellow;
#         }    #T_9d9240dc_d6c3_11e8_8634_c85b76e2a7ebrow9_col28 {
#             background-color:  yel

# %%
#export to csv
data1final.to_csv('Verizon PreProccessed.csv')
print("Preprocessing Completed In: %s seconds" % (time.time() - start_time))
# Out:
# Preprocessing Completed In: 3.1116411685943604 seconds
